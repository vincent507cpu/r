# %%
library(tidyverse)
setwd("~/Desktop")
chart <- read_csv("chart.csv", col_names = TRUE)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.0.0     ✔ purrr   0.2.5
# ✔ tibble  1.4.2     ✔ dplyr   0.7.6
# ✔ tidyr   0.8.1     ✔ stringr 1.3.1
# ✔ readr   1.1.1     ✔ forcats 0.3.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# Parsed with column specification:
# cols(
#   Name = col_character(),
#   Brand = col_character(),
#   Country = col_character(),
#   Current = col_number(),
#   New = col_number(),
#   Difference = col_number(),
#   Category = col_integer()
# )

# %%
graph <- chart %>%
  group_by(Category) %>%
  summarise(Number = n()) %>%
  ggplot() +
  geom_col(aes(y = Number, x = Category), fill = "black", color = "black") +
  geom_text(aes(label = Number, x = Category, y = Number),vjust=-0.2)

mytheme <- theme(plot.title = element_text(family = "Helvetica", face = "bold", size = (15)))

print(graph + mytheme + labs(title = "Number of hotels under each category", x = "Category", y = "Number") + scale_x_continuous(breaks = seq(1, 8, 1)))
# Out:
# plot without title

# %%
chart %>%
  group_by(Brand) %>%
  summarise(n = n())

chart %>%
  group_by(Difference) %>%
  summarise(n = n())
# Out:
#    Brand                       n
# 1  AC Hotels by Marriott        144
# 2  Aloft                        157
# 3  Autograph Collection         162
# 4  Courtyard                   1182
# 5  Delta                         65
# 6  Design Hotels                141
# 7  Edition                       10
# 8  Element                       40
# 9  Fairfield Inn                980
# 10 Four Points                  270
# 11 Gaylord Hotels                 6
# 12 JW Marriott                   84
# 13 Le Meridien                  109
# 14 Luxury Collection            113
# 15 Marriott                     571
# 16 Marriott Vacation Club Intl   64
# 17 Moxy Hotels                   33
# 18 Protea Hotels                 82
# 19 Renaissance                  172
# 20 Residence Inn                794
# 21 Ritz-Carlton                  94
# 22 Sheraton                     445
# 23 SpringHill Suites            410
# 24 St. Regis                     44
# 25 TownePlace Suites            369
# 26 Tribute Portfolio             29
# 27 VISTA                         19
# 28 W Hotels                      53
# 29 Westin                       222
#    Difference n
# 1  -30000        3
# 2  -25000        1
# 3  -12500       26
# 4  -11000       14
# 5  -10000      140
# 6   -8500       22
# 7   -7500      371
# 8   -5000     1002
# 9   -4500       20
# 10  -3500      173
# 11  -2500     1453
# 12  -1500       61
# 13  -1000      247
# 14      0     1144
# 15    500      121
# 16   2500     1020
# 17   3500       54
# 18   4000      164
# 19   5000      488
# 20   5500       75
# 21   7500       35
# 22  10000      122
# 23  13000        2
# 24  14000       50
# 25  15000       42
# 26  20000       10
# 27  24000        1
# 28  25000        2
# 29  40000        1

# %%
AC <- chart %>%
  filter(Brand == "AC Hotels by Marriott") %>%
  group_by(Category) %>%
  summarise("AC Hotels" = n())

Aloft <- chart %>%
  filter(Brand == "Aloft") %>%
  group_by(Category) %>%
  summarise("Aloft" = n())

Autograph <- chart %>%
  filter(Brand == "Autograph Collection") %>%
  group_by(Category) %>%
  summarise("Autograph Collection" = n())

Courtyard <- chart %>%
  filter(Brand == "Courtyard") %>%
  group_by(Category) %>%
  summarise(Courtyard = n())

Delta <- chart %>%
  filter(Brand == "Delta") %>%
  group_by(Category) %>%
  summarise(Delta = n())

Design <- chart %>%
  filter(Brand == "Design Hotels") %>%
  group_by(Category) %>%
  summarise("Design Hotels" = n())

Edition <- chart %>%
  filter(Brand == "Edition") %>%
  group_by(Category) %>%
  summarise(Edition = n())

Element <- chart %>%
  filter(Brand == "Element") %>%
  group_by(Category) %>%
  summarise(Element = n())

Fairfield <- chart %>%
  filter(Brand == "Fairfield Inn") %>%
  group_by(Category) %>%
  summarise("Fairfield Inn" = n())

FP <- chart %>%
  filter(Brand == "Four Points") %>%
  group_by(Category) %>%
  summarise("Four Points" = n())

Gaylord <- chart %>%
  filter(Brand == "Gaylord Hotels") %>%
  group_by(Category) %>%
  summarise("Gaylord Hotels" = n())

JW <- chart %>%
  filter(Brand == "JW Marriott") %>%
  group_by(Category) %>%
  summarise("JW Marriott" = n())

LM <- chart %>%
  filter(Brand == "Le Meridien") %>%
  group_by(Category) %>%
  summarise("Le Meridien" = n())

Luxury <- chart %>%
  filter(Brand == "Luxury Collection") %>%
  group_by(Category) %>%
  summarise("Luxury Collection" = n())

Marriott <- chart %>%
  filter(Brand == "Marriott") %>%
  group_by(Category) %>%
  summarise("Marriott" = n())

Club <- chart %>%
  filter(Brand == "Marriott Vacation Club Intl") %>%
  group_by(Category) %>%
  summarise("Marriott Vacation Club Intl" = n())

Moxy <- chart %>%
  filter(Brand == "Moxy Hotels" ) %>%
  group_by(Category) %>%
  summarise("Moxy Hotels"  = n())

Protea <- chart %>%
  filter(Brand == "Protea Hotels"  ) %>%
  group_by(Category) %>%
  summarise("Protea Hotels"   = n())

Renaissance <- chart %>%
  filter(Brand == "Renaissance") %>%
  group_by(Category) %>%
  summarise(Renaissance = n())

Residence <- chart %>%
  filter(Brand == "Residence Inn") %>%
  group_by(Category) %>%
  summarise("Residence Inn" = n())

Ritz <- chart %>%
  filter(Brand == "Ritz-Carlton") %>%
  group_by(Category) %>%
  summarise("Ritz-Carlton" = n())

Sheraton <- chart %>%
  filter(Brand == "Sheraton") %>%
  group_by(Category) %>%
  summarise(Sheraton = n())

SpringHill <- chart %>%
  filter(Brand == "SpringHill Suites") %>%
  group_by(Category) %>%
  summarise("SpringHill Suites" = n())

Regis <- chart %>%
  filter(Brand == "St. Regis") %>%
  group_by(Category) %>%
  summarise("St. Regis" = n())

TownPlace <- chart %>%
  filter(Brand == "TownePlace Suites") %>%
  group_by(Category) %>%
  summarise("TownePlace Suites" = n())

Tribute <- chart %>%
  filter(Brand == "Tribute Portfolio") %>%
  group_by(Category) %>%
  summarise("Tribute Portfolio" = n())

W <- chart %>%
  filter(Brand == "W Hotels") %>%
  group_by(Category) %>%
  summarise("W Hotels" = n())

Westin <- chart %>%
  filter(Brand == "Westin") %>%
  group_by(Category) %>%
  summarise("Westin" = n())

Category <- AC %>%
  full_join(Aloft, by = "Category") %>%
  full_join(Autograph, by = "Category") %>%
  full_join(Courtyard, by = "Category") %>%
  full_join(Delta, by = "Category") %>%
  full_join(Design, by = "Category") %>%
  full_join(Edition, by = "Category") %>%
  full_join(Fairfield, by = "Category") %>%
  full_join(FP, by = "Category") %>%
  full_join(Gaylord, by = "Category") %>%
  full_join(JW, by = "Category") %>%
  full_join(LM, by = "Category") %>%
  full_join(Luxury, by = "Category") %>%
  full_join(Marriott, by = "Category") %>%
  full_join(Moxy, by = "Category") %>%
  full_join(Protea, by = "Category") %>%
  full_join(Regis, by = "Category") %>%
  full_join(Renaissance, by = "Category") %>%
  full_join(Residence, by = "Category") %>%
  full_join(Ritz, by = "Category") %>%
  full_join(Sheraton, by = "Category") %>%
  full_join(SpringHill, by = "Category") %>%
  full_join(TownPlace, by = "Category") %>%
  full_join(Tribute, by = "Category") %>%
  full_join(W, by = "Category") %>%
  full_join(Westin, by = "Category")
t(Category)
# Out:
#                      [,1] [,2] [,3] [,4] [,5] [,6] [,7] [,8]
# Category               1    2    3    4    5   6    7    8
# AC Hotels             26   23   30   43   22  NA   NA   NA
# Aloft                 25   17   44   56   15  NA   NA   NA
# Autograph Collection  NA    6    8   22   79  40    6    1
# Courtyard             69  280  460  255  112   6   NA   NA
# Delta                 NA    5   18   26   15   1   NA   NA
# Design Hotels         NA    2    1   31   63   7   30    7
# Edition               NA   NA   NA   NA    4   1    4    1
# Fairfield Inn        102  297  396  136   46   3   NA   NA
# Four Points           53   62   82   53   20  NA   NA   NA
# Gaylord Hotels        NA   NA   NA    1    5  NA   NA   NA
# JW Marriott           NA    6   12   17   28  17    4   NA
# Le Meridien           NA   16   19   22   39   9    3    1
# Luxury Collection     NA    5    4   10   31  17   24   22
# Marriott              NA   53  107  190  169  47    5   NA
# Moxy Hotels           NA    3   11   14    5  NA   NA   NA
# Protea Hotels         64   14    3    1   NA  NA   NA   NA
# St. Regis             NA   NA   NA    3   11   8    8   14
# Renaissance           NA   26   23   55   53  14    1   NA
# Residence Inn         12  146  322  226   82   6   NA   NA
# Ritz-Carlton          NA   NA   NA    4   23  32   25   10
# Sheraton              NA   84   82  154  105  15    5   NA
# SpringHill Suites     10  107  147  107   37   2   NA   NA
# TownePlace Suites     33  121  154   56    5  NA   NA   NA
# Tribute Portfolio     NA   NA   NA   12   12   5   NA   NA
# W Hotels              NA   NA   NA    6   18  13   12    4
# Westin                NA    7   16   62  103  23   10    1

# %%
(Difference <- chart %>%
  arrange(desc(Difference)) %>%
  filter(Difference >= 14000) %>%
  select(Name, Difference, Current, New, Brand) %>%
  filter(Current != 70000) %>%
  select(Name))
# Out:
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”ERROR while rich displaying an object: Error in gsub(" &\\", "\\", r, fixed = TRUE): input string 1 is invalid in this locale
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. mime2repr[[mime]](obj)
# 8. repr_latex.data.frame(obj)
# 9. gsub(" &\\", "\\", r, fixed = TRUE)
# Warning message in grepl("<html.*>", data[["text/html"]], ignore.case = TRUE):
# “input string 1 is invalid in this locale”
#    Name
# 1  Domes of Elounda, Autograph Collection
# 2  Blue Palace, a Luxury Collection Resort and Spa, Crete
# 3  The St. Regis Rome
# 4  The Westin Riverfront Mountain Villas, Beaver Creek Mountain
# 5  Marriott's Club Son Antem
# 6  Sheraton Broadway Plantation Resort Villas
# 7  Sheraton on the Falls Hotel
# 8  Sheraton Vistana Resort Villas, Lake Buena Vista/Orlando
# 9  Sheraton Vistana Villages Resort Villas, I-Drive/Orlando
# 10 Vistana Beach Club
# 11 Marriott's Kauai Lagoons - Kalanipu'u
# 12 Marriott's Newport Coast Villas
# 13 Marriott's Waiohai Beach Club
# 14 Marriott\xd5s Waikoloa Ocean Club
# 15 Fairfield Inn & Suites Virgin Zion National Park
# 16 Marriott Vacation Club Pulse, San Diego
# 17 Marriott's Cypress Harbour Villas
# 18 Marriott's Fairway Villas
# 19 Marriott's Imperial Palms Villas
# 20 Marriott's Marbella Beach Resort
# 21 Marriott's Royal Palms
# 22 Marriott's Sabal Palms
# 23 Marriott's St. Kitts Beach Club
# 24 SpringHill Suites Springdale Zion National Park
# 25 Boscolo Exedra Roma, Autograph Collection
# 26 Cotton House Hotel, Autograph Collection
# 27 Domes Noruz Chania, Autograph Collection
# 28 Grosvenor House, A JW Marriott Hotel
# 29 JW Marriott Essex House New York
# 30 JW Marriott Nashville
# ⋮  ⋮
# 66 Sheraton Grand Hotel & Spa, Edinburgh
# 67 Sheraton Hong Kong Hotel & Towers
# 68 Sheraton Lakeside Terrace Villas at Mountain Vista, Avon, Vail Valley
# 69 Sheraton Miyako Hotel Tokyo
# 70 Sheraton New York Times Square Hotel
# 71 The Ballantyne, a Luxury Collection Hotel, Charlotte
# 72 The Equinox, a Luxury Collection Golf Resort & Spa, Vermont
# 73 The Inn at Rancho Santa Fe, a Tribute Portfolio Resort & Spa
# 74 The Nines, a Luxury Collection Hotel, Portland
# 75 The St. Regis Moscow Nikolskaya
# 76 THE US GRANT, a Luxury Collection Hotel, San Diego
# 77 The Westin Boston Waterfront
# 78 The Westin Copley Place, Boston
# 79 The Westin Desert Willow Villas, Palm Desert
# 80 The Westin Grand Cayman Seven Mile Beach Resort & Spa
# 81 The Westin Grand, Vancouver
# 82 The Westin Kierland Villas
# 83 The Westin Mission Hills Resort Villas, Palm Springs
# 84 The Westin Monache Resort, Mammoth
# 85 The Westin Nashville
# 86 The Westin San Diego
# 87 The Westin San Diego Gaslamp Quarter
# 88 The Westin Seattle
# 89 The Westin St. Francis San Francisco on Union Square
# 90 The Westin Trillium House, Blue Mountain
# 91 Twelve at Hengshan, a Luxury Collection Hotel, Shanghai
# 92 W Fort Lauderdale
# 93 W Seattle
# 94 Walt Disney World Dolphin
# 95 Walt Disney World Swan

# %%
(Difference2 <- chart %>%
  filter(New == 85000)  %>%
  select(Name))
# Out:
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”ERROR while rich displaying an object: Error in gsub(" &\\", "\\", r, fixed = TRUE): input string 1 is invalid in this locale
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. mime2repr[[mime]](obj)
# 8. repr_latex.data.frame(obj)
# 9. gsub(" &\\", "\\", r, fixed = TRUE)
# Warning message in grepl("<html.*>", data[["text/html"]], ignore.case = TRUE):
# “input string 1 is invalid in this locale”
#    Name
# 1  11 Howard, New York, a Member of Design Hotels\xaa
# 2  Al Maha, a Luxury Collection Desert Resort & Spa, Dubai
# 3  Blue Palace, a Luxury Collection Resort and Spa, Crete
# 4  Cristallo, a Luxury Collection Resort & Spa, Cortina d'Ampezzo
# 5  Domes of Elounda, Autograph Collection
# 6  G-Rough, Rome, a Member of Design Hotels
# 7  Giardino Ascona, A Member Of Design Hotels
# 8  Giardino Mountain, a Member of Design Hotels
# 9  Hotel Cala di Volpe, a Luxury Collection Hotel, Costa Smeralda
# 10 Hotel Danieli, a Luxury Collection Hotel, Venice
# 11 Hotel Pitrizza, a Luxury Collection Hotel, Costa Smeralda
# 12 Hotel President Wilson, a Luxury Collection Hotel, Geneva
# 13 Hotel Romazzino, a Luxury Collection Hotel, Costa Smeralda
# 14 H\x99tel de Berri, a Luxury Collection Hotel, Paris
# 15 Kenoa Exclusive Beach Spa & Resort, Barra de Sao Miguel, a Member of Design Hotels
# 16 Le M\x8eridien Bora Bora
# 17 Mystique, A Luxury Collection Resort, Santorini
# 18 PalazzinaG, Venice, a Member of Design Hotels
# 19 Parklane, a Luxury Collection Resort & Spa, Limassol
# 20 Phoenician Residences, a Luxury Collection Residence Club, Scottsdale
# 21 Prince de Galles, a Luxury Collection Hotel, Paris
# 22 Santa Marina, a Luxury Collection Resort, Mykonos
# 23 Schloss Fuschl, a Luxury Collection Resort & Spa, Fuschlsee-Salzburg
# 24 Sir Joan Hotel, Ibiza City, a Member of Design Hotels
# 25 Suiran, a Luxury Collection Hotel, Kyoto
# 26 The Canyon Suites at The Phoenician, a Luxury Collection Resort, Scottsdale
# 27 The Chatwal, a Luxury Collection Hotel, New York City
# 28 The Gritti Palace, a Luxury Collection Hotel, Venice
# 29 The Miami Beach EDITION
# 30 The Prince Gallery Tokyo Kioicho, a Luxury Collection Hotel
# ⋮  ⋮
# 32 The Ritz-Carlton New York, Central Park
# 33 The Ritz-Carlton, Bachelor Gulch
# 34 The Ritz-Carlton, Grand Cayman
# 35 The Ritz-Carlton, Hong Kong
# 36 The Ritz-Carlton, Kyoto
# 37 The Ritz-Carlton, Lake Tahoe
# 38 The Ritz-Carlton, Naples
# 39 The Ritz-Carlton, St. Thomas
# 40 The Ritz-Carlton, Tokyo
# 41 The St. Regis Aspen Resort
# 42 The St. Regis Bahia Beach Resort, Puerto Rico
# 43 The St. Regis Bal Harbour Resort
# 44 The St. Regis Bali Resort
# 45 The St. Regis Bora Bora Resort
# 46 The St. Regis Deer Valley
# 47 The St. Regis Florence
# 48 The St. Regis Maldives Vommuli Resort
# 49 The St. Regis Mardavall Mallorca Resort
# 50 The St. Regis New York
# 51 The St. Regis Osaka
# 52 The St. Regis Princeville Resort
# 53 The St. Regis Punta Mita Resort
# 54 The St. Regis Rome
# 55 The Wellesley Knightsbridge, a Luxury Collection Hotel, London
# 56 The Westin Golf Resort & Spa, Playa Conchal
# 57 Vana Belle, a Luxury Collection Resort, Koh Samui
# 58 W Koh Samui
# 59 W Maldives
# 60 W South Beach
# 61 W Verbier

# %%
(Difference3 <- chart %>%
  arrange(desc(Difference)) %>%
  filter(Difference <= -10000) %>%
  select(Name, Difference, Current, New) %>%
  filter(New >= 50000) %>%
  select(Name))
# Out:
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”ERROR while rich displaying an object: Error in gsub(" &\\", "\\", r, fixed = TRUE): input string 1 is invalid in this locale
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. mime2repr[[mime]](obj)
# 8. repr_latex.data.frame(obj)
# 9. gsub(" &\\", "\\", r, fixed = TRUE)
# Warning message in grepl("<html.*>", data[["text/html"]], ignore.case = TRUE):
# “input string 1 is invalid in this locale”
#    Name
# 1  Anemi Hotel, Folegandros Island, a Member of Design Hotels\xaa
# 2  Caresse, a Luxury Collection Resort & Spa, Bodrum
# 3  Ch\x89teau de la Resle, a Member of Design Hotels\xaa
# 4  Elma Arts Complex Luxury Hotel, a Member of Design Hotels
# 5  Hacienda Uayamon, a Luxury Collection Hotel, Uayamon
# 6  Hotel Imperial, a Luxury Collection Hotel, Vienna
# 7  Hotel Talisa, Vail
# 8  Keraton at The Plaza, a Luxury Collection Hotel, Jakarta
# 9  Las Alcobas, a Luxury Collection Hotel, Mexico City
# 10 Le M\x8eridien Barcelona
# 11 Le M\x8eridien San Francisco
# 12 Le M\x8eridien Taipei
# 13 Mykonos Theoxenia, a Member of Design Hotels\xaa
# 14 Noelle, Nashville, a Tribute Portfolio Hotel
# 15 Palace Hotel, a Luxury Collection Hotel, San Francisco
# 16 Papaya Playa Project, Tulum, a Member of Design Hotels
# 17 San Francisco Proper, a Member of Design Hotels\xaa
# 18 Sheraton Bijao Beach Resort
# 19 Sheraton Grande Tokyo Bay Hotel
# 20 Sheraton Kuwait, a Luxury Collection Hotel, Kuwait City
# 21 Sheraton Maui Resort & Spa
# 22 Sheraton Okinawa Sunmarina Resort
# 23 Sheraton Tel Aviv Hotel
# 24 Sheraton Waikiki
# 25 The Naka Phuket, a Member of Design Hotels
# 26 The Ritz-Carlton Key Biscayne, Miami
# 27 The Ritz-Carlton, Sarasota
# 28 The St. Regis Dubai, Al Habtoor Polo Resort & Club
# 29 The St. Regis Houston
# 30 The St. Regis Kuala Lumpur
# ⋮  ⋮
# 35 The Westin Bonaventure Hotel & Suites, Los Angeles
# 36 The Westin Excelsior, Rome
# 37 The Westin Ka'anapali Ocean Resort Villas
# 38 The Westin Lagunamar Ocean Resort Villas & Spa, Cancun
# 39 The Westin Los Cabos Resort Villas & Spa
# 40 The Westin Maui Resort & Spa, Ka'anapali
# 41 The Westin New York at Times Square
# 42 The Westin New York Grand Central
# 43 The Westin Palace, Madrid
# 44 The Westin Palo Alto
# 45 The Westin Singapore
# 46 The Westin Tokyo
# 47 The Westin Verasa Napa
# 48 W Austin
# 49 W Bellevue
# 50 W Boston
# 51 W Hoboken
# 52 W Montr\x8eal
# 53 W New York \xd0 Downtown
# 54 W Punta de Mita
# 55 W San Francisco
# 56 W Shanghai - The Bund
# 57 W Singapore - Sentosa Cove
# 58 W Taipei
# 59 The Ritz-Carlton Shanghai, Pudong
# 60 The Ritz-Carlton, Dubai
# 61 The Ritz-Carlton, South Beach
# 62 Las Alcobas, a Luxury Collection Hotel, Napa Valley
# 63 The St. Regis San Francisco
# 64 W Bali - Seminyak

# %%
(Difference4 <- chart %>%
  arrange(Difference) %>%
  select(Name, Difference, Current, New) %>%
  filter(New >= 50000) %>%
  filter(Difference <= -10000))
# Out:
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”ERROR while rich displaying an object: Error in gsub(" &\\", "\\", r, fixed = TRUE): input string 1 is invalid in this locale
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. mime2repr[[mime]](obj)
# 8. repr_latex.data.frame(obj)
# 9. gsub(" &\\", "\\", r, fixed = TRUE)
# Warning message in grepl("<html.*>", data[["text/html"]], ignore.case = TRUE):
# “input string 1 is invalid in this locale”
#    Name                                                           Difference
# 1  Las Alcobas, a Luxury Collection Hotel, Napa Valley            -30000
# 2  The St. Regis San Francisco                                    -30000
# 3  W Bali - Seminyak                                              -30000
# 4  Anemi Hotel, Folegandros Island, a Member of Design Hotels\xaa -10000
# 5  Caresse, a Luxury Collection Resort & Spa, Bodrum              -10000
# 6  Ch\x89teau de la Resle, a Member of Design Hotels\xaa          -10000
# 7  Elma Arts Complex Luxury Hotel, a Member of Design Hotels      -10000
# 8  Hacienda Uayamon, a Luxury Collection Hotel, Uayamon           -10000
# 9  Hotel Imperial, a Luxury Collection Hotel, Vienna              -10000
# 10 Hotel Talisa, Vail                                             -10000
# 11 Keraton at The Plaza, a Luxury Collection Hotel, Jakarta       -10000
# 12 Las Alcobas, a Luxury Collection Hotel, Mexico City            -10000
# 13 Le M\x8eridien Barcelona                                       -10000
# 14 Le M\x8eridien San Francisco                                   -10000
# 15 Le M\x8eridien Taipei                                          -10000
# 16 Mykonos Theoxenia, a Member of Design Hotels\xaa               -10000
# 17 Noelle, Nashville, a Tribute Portfolio Hotel                   -10000
# 18 Palace Hotel, a Luxury Collection Hotel, San Francisco         -10000
# 19 Papaya Playa Project, Tulum, a Member of Design Hotels         -10000
# 20 San Francisco Proper, a Member of Design Hotels\xaa            -10000
# 21 Sheraton Bijao Beach Resort                                    -10000
# 22 Sheraton Grande Tokyo Bay Hotel                                -10000
# 23 Sheraton Kuwait, a Luxury Collection Hotel, Kuwait City        -10000
# 24 Sheraton Maui Resort & Spa                                     -10000
# 25 Sheraton Okinawa Sunmarina Resort                              -10000
# 26 Sheraton Tel Aviv Hotel                                        -10000
# 27 Sheraton Waikiki                                               -10000
# 28 The Naka Phuket, a Member of Design Hotels                     -10000
# 29 The Ritz-Carlton Key Biscayne, Miami                           -10000
# 30 The Ritz-Carlton, Sarasota                                     -10000
# ⋮  ⋮                                                              ⋮
# 35 The St. Regis Mexico City                                      -10000
# 36 The St. Regis Saadiyat Island Resort, Abu Dhabi                -10000
# 37 The St. Regis Sanya Yalong Bay Resort                          -10000
# 38 The Westin Bonaventure Hotel & Suites, Los Angeles             -10000
# 39 The Westin Excelsior, Rome                                     -10000
# 40 The Westin Ka'anapali Ocean Resort Villas                      -10000
# 41 The Westin Lagunamar Ocean Resort Villas & Spa, Cancun         -10000
# 42 The Westin Los Cabos Resort Villas & Spa                       -10000
# 43 The Westin Maui Resort & Spa, Ka'anapali                       -10000
# 44 The Westin New York at Times Square                            -10000
# 45 The Westin New York Grand Central                              -10000
# 46 The Westin Palace, Madrid                                      -10000
# 47 The Westin Palo Alto                                           -10000
# 48 The Westin Singapore                                           -10000
# 49 The Westin Tokyo                                               -10000
# 50 The Westin Verasa Napa                                         -10000
# 51 W Austin                                                       -10000
# 52 W Bellevue                                                     -10000
# 53 W Boston                                                       -10000
# 54 W Hoboken                                                      -10000
# 55 W Montr\x8eal                                                  -10000
# 56 W New York \xd0 Downtown                                       -10000
# 57 W Punta de Mita                                                -10000
# 58 W San Francisco                                                -10000
# 59 W Shanghai - The Bund                                          -10000
# 60 W Singapore - Sentosa Cove                                     -10000
# 61 W Taipei                                                       -10000
# 62 The Ritz-Carlton Shanghai, Pudong                              -10000
# 63 The Ritz-Carlton, Dubai                                        -10000
# 64 The Ritz-Carlton, South Beach                                  -10000
#    Current New
# 1  90000   60000
# 2  90000   60000
# 3  90000   60000
# 4  60000   50000
# 5  60000   50000
# 6  60000   50000
# 7  60000   50000
# 8  60000   50000
# 9  60000   50000
# 10 60000   50000
# 11 60000   50000
# 12 60000   50000
# 13 60000   50000
# 14 60000   50000
# 15 60000   50000
# 16 60000   50000
# 17 60000   50000
# 18 60000   50000
# 19 60000   50000
# 20 60000   50000
# 21 60000   50000
# 22 60000   50000
# 23 60000   50000
# 24 60000   50000
# 25 60000   50000
# 26 60000   50000
# 27 60000   50000
# 28 60000   50000
# 29 60000   50000
# 30 60000   50000
# ⋮  ⋮       ⋮
# 35 60000   50000
# 36 60000   50000
# 37 60000   50000
# 38 60000   50000
# 39 60000   50000
# 40 60000   50000
# 41 60000   50000
# 42 60000   50000
# 43 60000   50000
# 44 60000   50000
# 45 60000   50000
# 46 60000   50000
# 47 60000   50000
# 48 60000   50000
# 49 60000   50000
# 50 60000   50000
# 51 60000   50000
# 52 60000   50000
# 53 60000   50000
# 54 60000   50000
# 55 60000   50000
# 56 60000   50000
# 57 60000   50000
# 58 60000   50000
# 59 60000   50000
# 60 60000   50000
# 61 60000   50000
# 62 70000   60000
# 63 70000   60000
# 64 70000   60000

# %%
(US50000 <- chart %>%
  filter(New == 50000, Country == "USA", Brand %in% c(
    "Marriott", "W Hotels", "Sheraton", "Westin", "Luxury Collection", "JW Marriott", 
    "Autograph Collection", "Ritz-Carton")))
# Out:
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”ERROR while rich displaying an object: Error in gsub(" &\\", "\\", r, fixed = TRUE): input string 1 is invalid in this locale
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. mime2repr[[mime]](obj)
# 8. repr_latex.data.frame(obj)
# 9. gsub(" &\\", "\\", r, fixed = TRUE)
# Warning message in grepl("<html.*>", data[["text/html"]], ignore.case = TRUE):
# “input string 1 is invalid in this locale”
#    Name                                                  Brand
# 1  Beverly Hills Marriott                                Marriott
# 2  Boston Marriott Cambridge                             Marriott
# 3  Boston Marriott Copley Place                          Marriott
# 4  Boston Marriott Long Wharf                            Marriott
# 5  Cadillac Hotel & Beach Club, Autograph Collection     Autograph Collection
# 6  Casa Monica Resort & Spa, Autograph Collection        Autograph Collection
# 7  Clearwater Beach Marriott Suites on Sand Key          Marriott
# 8  Coronado Island Marriott Resort & Spa                 Marriott
# 9  Fort Lauderdale Marriott Harbor Beach Resort & Spa    Marriott
# 10 Grand Bohemian Hotel Asheville, Autograph Collection  Autograph Collection
# 11 Grand Bohemian Hotel Charleston, Autograph Collection Autograph Collection
# 12 Hi-Lo Hotel, Autograph Collection                     Autograph Collection
# 13 Hotel Adagio, Autograph Collection                    Autograph Collection
# 14 Hotel Beaux Arts, Autograph Collection                Autograph Collection
# 15 Hotel Park City, Autograph Collection                 Autograph Collection
# 16 Hotel Talisa, Vail                                    Luxury Collection
# 17 JW Marriott Austin                                    JW Marriott
# 18 JW Marriott Desert Springs Resort & Spa               JW Marriott
# 19 JW Marriott Los Angeles L.A. LIVE                     JW Marriott
# 20 JW Marriott Marco Island Beach Resort                 JW Marriott
# 21 JW Marriott Orlando, Grande Lakes                     JW Marriott
# 22 JW Marriott Phoenix Desert Ridge Resort & Spa         JW Marriott
# 23 JW Marriott San Antonio Hill Country Resort & Spa     JW Marriott
# 24 JW Marriott San Francisco Union Square                JW Marriott
# 25 JW Marriott Scottsdale Camelback Inn Resort & Spa     JW Marriott
# 26 JW Marriott Washington, DC                            JW Marriott
# 27 Kaua'i Marriott Resort                                Marriott
# 28 Key Largo Bay Marriott Beach Resort                   Marriott
# 29 Key West Marriott Beachside Hotel                     Marriott
# 30 Lido House, Autograph Collection                      Autograph Collection
# ⋮  ⋮                                                     ⋮
# 70 The Saint Hotel Key West, Autograph Collection        Autograph Collection
# 71 THE US GRANT, a Luxury Collection Hotel, San Diego    Luxury Collection
# 72 The Westin Bonaventure Hotel & Suites, Los Angeles    Westin
# 73 The Westin Boston Waterfront                          Westin
# 74 The Westin Copley Place, Boston                       Westin
# 75 The Westin Maui Resort & Spa, Ka'anapali              Westin
# 76 The Westin Monache Resort, Mammoth                    Westin
# 77 The Westin Nashville                                  Westin
# 78 The Westin New York at Times Square                   Westin
# 79 The Westin New York Grand Central                     Westin
# 80 The Westin Palo Alto                                  Westin
# 81 The Westin San Diego                                  Westin
# 82 The Westin San Diego Gaslamp Quarter                  Westin
# 83 The Westin Seattle                                    Westin
# 84 The Westin St. Francis San Francisco on Union Square  Westin
# 85 The Westin Verasa Napa                                Westin
# 86 W Austin                                              W Hotels
# 87 W Bellevue                                            W Hotels
# 88 W Boston                                              W Hotels
# 89 W Fort Lauderdale                                     W Hotels
# 90 W Hoboken                                             W Hotels
# 91 W New York \xd0 Downtown                              W Hotels
# 92 W San Francisco                                       W Hotels
# 93 W Seattle                                             W Hotels
# 94 Waikiki Beach Marriott Resort & Spa                   Marriott
# 95 Waikoloa Beach Marriott Resort & Spa                  Marriott
# 96 Wailea Beach Resort - Marriott, Maui                  Marriott
# 97 Walt Disney World Dolphin                             Sheraton
# 98 Walt Disney World Swan                                Westin
# 99 Wentworth by the Sea, A Marriott Hotel & Spa          Marriott
#    Country Current New   Difference Category
# 1  USA     40000   50000  10000     6
# 2  USA     40000   50000  10000     6
# 3  USA     40000   50000  10000     6
# 4  USA     45000   50000   5000     6
# 5  USA     40000   50000  10000     6
# 6  USA     40000   50000  10000     6
# 7  USA     40000   50000  10000     6
# 8  USA     40000   50000  10000     6
# 9  USA     40000   50000  10000     6
# 10 USA     45000   50000   5000     6
# 11 USA     45000   50000   5000     6
# 12 USA     40000   50000  10000     6
# 13 USA     45000   50000   5000     6
# 14 USA     40000   50000  10000     6
# 15 USA     45000   50000   5000     6
# 16 USA     60000   50000 -10000     6
# 17 USA     40000   50000  10000     6
# 18 USA     40000   50000  10000     6
# 19 USA     40000   50000  10000     6
# 20 USA     45000   50000   5000     6
# 21 USA     40000   50000  10000     6
# 22 USA     40000   50000  10000     6
# 23 USA     40000   50000  10000     6
# 24 USA     45000   50000   5000     6
# 25 USA     40000   50000  10000     6
# 26 USA     45000   50000   5000     6
# 27 USA     40000   50000  10000     6
# 28 USA     40000   50000  10000     6
# 29 USA     45000   50000   5000     6
# 30 USA     45000   50000   5000     6
# ⋮  ⋮       ⋮       ⋮     ⋮          ⋮
# 70 USA     45000   50000   5000     6
# 71 USA     36000   50000  14000     6
# 72 USA     60000   50000 -10000     6
# 73 USA     36000   50000  14000     6
# 74 USA     36000   50000  14000     6
# 75 USA     60000   50000 -10000     6
# 76 USA     36000   50000  14000     6
# 77 USA     36000   50000  14000     6
# 78 USA     60000   50000 -10000     6
# 79 USA     60000   50000 -10000     6
# 80 USA     60000   50000 -10000     6
# 81 USA     36000   50000  14000     6
# 82 USA     36000   50000  14000     6
# 83 USA     36000   50000  14000     6
# 84 USA     36000   50000  14000     6
# 85 USA     60000   50000 -10000     6
# 86 USA     60000   50000 -10000     6
# 87 USA     60000   50000 -10000     6
# 88 USA     60000   50000 -10000     6
# 89 USA     36000   50000  14000     6
# 90 USA     60000   50000 -10000     6
# 91 USA     60000   50000 -10000     6
# 92 USA     60000   50000 -10000     6
# 93 USA     36000   50000  14000     6
# 94 USA     40000   50000  10000     6
# 95 USA     40000   50000  10000     6
# 96 USA     40000   50000  10000     6
# 97 USA     36000   50000  14000     6
# 98 USA     36000   50000  14000     6
# 99 USA     45000   50000   5000     6

# %%
(CN <- chart %>%
  filter(Country == "China", New %in% c(35000, 50000, 60000), !str_detect(Name, "Airport")) %>%
  select(Name, New))
# Out:
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”ERROR while rich displaying an object: Error in gsub(" &\\", "\\", r, fixed = TRUE): input string 1 is invalid in this locale
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. mime2repr[[mime]](obj)
# 8. repr_latex.data.frame(obj)
# 9. gsub(" &\\", "\\", r, fixed = TRUE)
# Warning message in grepl("<html.*>", data[["text/html"]], ignore.case = TRUE):
# “input string 1 is invalid in this locale”
#    Name                                                       New
# 1  Hong Kong Ocean Park Marriott Hotel                        35000
# 2  JW Marriott Hotel Macau                                    35000
# 3  JW Marriott Hotel Shanghai at Tomorrow Square              35000
# 4  Le M\x8eridien Xiaojing Bay                                35000
# 5  Mira Moon Hong Kong, a Member of Design Hotels\xaa         35000
# 6  Renaissance Hong Kong Harbour View Hotel                   35000
# 7  Sanya Marriott Yalong Bay Resort & Spa                     35000
# 8  Sheraton Dameisha Resort, Shenzhen                         35000
# 9  Sheraton Grand Macao Hotel, Cotai Central                  35000
# 10 Sheraton Huzhou Hot Spring Resort                          35000
# 11 Sheraton Sanya Resort                                      35000
# 12 The Castle Hotel, a Luxury Collection Hotel, Dalian        35000
# 13 The Mira Hong Kong, a Member of Design Hotels\xaa          35000
# 14 The Portman Ritz-Carlton, Shanghai                         35000
# 15 The Ritz-Carlton Beijing, Financial Street                 35000
# 16 The Ritz-Carlton, Beijing                                  35000
# 17 The Ritz-Carlton, Guangzhou                                35000
# 18 The Ritz-Carlton, Shenzhen                                 35000
# 19 The Royal Begonia, a Luxury Collection Resort, Sanya       35000
# 20 The Sanya EDITION                                          35000
# 21 The St. Regis Beijing                                      35000
# 22 The St. Regis Lhasa Resort                                 35000
# 23 The St. Regis Shanghai Jingan                              35000
# 24 The St. Regis Shenzhen                                     35000
# 25 The Waterhouse at South Bund, a Member of Design Hotels    35000
# 26 The Westin Bund Center, Shanghai                           35000
# 27 The Westin Changbaishan Resort                             35000
# 28 The Westin Sanya Haitang Bay Resort                        35000
# 29 The Westin Zhujiajian Resort, Zhoushan                     35000
# 30 W Guangzhou                                                35000
# 31 JW Marriott Hotel Hong Kong                                50000
# 32 Sheraton Hong Kong Hotel & Towers                          50000
# 33 The Ritz-Carlton Sanya, Yalong Bay                         50000
# 34 The Ritz-Carlton, Macau                                    50000
# 35 The Shanghai EDITION                                       50000
# 36 The St. Regis Sanya Yalong Bay Resort                      50000
# 37 Twelve at Hengshan, a Luxury Collection Hotel, Shanghai    50000
# 38 W Shanghai - The Bund                                      50000
# 39 The Ritz-Carlton Shanghai, Pudong                          60000
# 40 The St. Regis Macao, Cotai Central                         60000
# 41 W Hong Kong                                                60000

# %%
(LA <- chart %>%
  filter(str_detect(Name, "Los Angeles|Hollywood|Beverly Hills"), !str_detect(Name, "Airport"), New %in% c(35000, 50000, 60000)) %>%
  select(Name, New))
# Out:
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”ERROR while rich displaying an object: Error in gsub(" &\\", "\\", r, fixed = TRUE): input string 1 is invalid in this locale
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. mime2repr[[mime]](obj)
# 8. repr_latex.data.frame(obj)
# 9. gsub(" &\\", "\\", r, fixed = TRUE)
# Warning message in grepl("<html.*>", data[["text/html"]], ignore.case = TRUE):
# “input string 1 is invalid in this locale”
#    Name                                                      New
# 1  AC Hotel Beverly Hills                                    35000
# 2  Avalon Hotel Beverly Hills, a Member of Design Hotels\xaa 35000
# 3  Courtyard Los Angeles Century City/Beverly Hills          35000
# 4  Courtyard Los Angeles L.A. LIVE                           35000
# 5  Courtyard Los Angeles LAX/Century Boulevard               35000
# 6  Courtyard Los Angeles LAX/El Segundo                      35000
# 7  Courtyard Los Angeles Pasadena/Old Town                   35000
# 8  Courtyard Los Angeles Sherman Oaks                        35000
# 9  Courtyard Los Angeles Westside                            35000
# 10 Four Points by Sheraton Los Angeles Westside              35000
# 11 Hollywood Beach Marriott                                  35000
# 12 Residence Inn Beverly Hills                               35000
# 13 Residence Inn Los Angeles Burbank/Downtown                35000
# 14 Residence Inn Los Angeles L.A. LIVE                       35000
# 15 Residence Inn Los Angeles LAX/Century Boulevard           35000
# 16 Residence Inn Los Angeles LAX/El Segundo                  35000
# 17 Residence Inn Los Angeles Pasadena/Old Town               35000
# 18 Sheraton Gateway Los Angeles Hotel                        35000
# 19 Sheraton Grand Los Angeles                                35000
# 20 Sheraton Los Angeles San Gabriel                          35000
# 21 SpringHill Suites Los Angeles Burbank/Downtown            35000
# 22 Beverly Hills Marriott                                    50000
# 23 JW Marriott Los Angeles L.A. LIVE                         50000
# 24 The Westin Bonaventure Hotel & Suites, Los Angeles        50000
# 25 SLS Hotel, a Luxury Collection Hotel, Beverly Hills       60000
# 26 The Ritz-Carlton, Los Angeles                             60000
# 27 W Hollywood                                               60000
# 28 W Los Angeles - West Beverly Hills                        60000

# %%
(SF <- chart %>%
  filter(str_detect(Name, "San Francisco"), !str_detect(Name, "Airport"), New %in% c(35000, 50000, 60000)) %>%
  select(Name, New))
# Out:
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”ERROR while rich displaying an object: Error in gsub(" &\\", "\\", r, fixed = TRUE): input string 1 is invalid in this locale
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. mime2repr[[mime]](obj)
# 8. repr_latex.data.frame(obj)
# 9. gsub(" &\\", "\\", r, fixed = TRUE)
# Warning message in grepl("<html.*>", data[["text/html"]], ignore.case = TRUE):
# “input string 1 is invalid in this locale”
#    Name                                                      New
# 1  Courtyard San Francisco Downtown                          35000
# 2  Courtyard San Francisco Fisherman's Wharf                 35000
# 3  Courtyard San Francisco Larkspur Landing/Marin County     35000
# 4  Courtyard San Francisco Union Square                      35000
# 5  The Park Central San Francisco                            35000
# 6  JW Marriott San Francisco Union Square                    50000
# 7  Le M\x8eridien San Francisco                              50000
# 8  Palace Hotel, a Luxury Collection Hotel, San Francisco    50000
# 9  San Francisco Marriott Fisherman's Wharf                  50000
# 10 San Francisco Marriott Marquis                            50000
# 11 San Francisco Marriott Union Square                       50000
# 12 San Francisco Proper, a Member of Design Hotels\xaa       50000
# 13 The Westin St. Francis San Francisco on Union Square      50000
# 14 W San Francisco                                           50000
# 15 The Ritz-Carlton, San Francisco                           60000
# 16 The St. Regis San Francisco                               60000

# %%
(NY <- chart %>%
  filter(str_detect(Name, "New York"), !str_detect(Name, "Airport"), New %in% c(35000, 50000, 60000)) %>%
  select(Name, New))
# Out:
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”ERROR while rich displaying an object: Error in gsub(" &\\", "\\", r, fixed = TRUE): input string 1 is invalid in this locale
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. mime2repr[[mime]](obj)
# 8. repr_latex.data.frame(obj)
# 9. gsub(" &\\", "\\", r, fixed = TRUE)
# Warning message in grepl("<html.*>", data[["text/html"]], ignore.case = TRUE):
# “input string 1 is invalid in this locale”
#    Name                                                              New
# 1  AC Hotel New York Times Square                                    35000
# 2  Courtyard New York Manhattan/Central Park                         35000
# 3  Courtyard New York Manhattan/Chelsea                              35000
# 4  Courtyard New York Manhattan/Fifth Avenue                         35000
# 5  Courtyard New York Manhattan/Herald Square                        35000
# 6  Courtyard New York Manhattan/Midtown East                         35000
# 7  Courtyard New York Manhattan/SoHo                                 35000
# 8  Courtyard New York Manhattan/Times Square                         35000
# 9  Courtyard New York Manhattan/Times Square West                    35000
# 10 Courtyard New York Manhattan/Upper East Side                      35000
# 11 Element New York Times Square West                                35000
# 12 Fairfield Inn & Suites New York Manhattan/Central Park            35000
# 13 Fairfield Inn & Suites New York Manhattan/Chelsea                 35000
# 14 Fairfield Inn & Suites New York Manhattan/Fifth Avenue            35000
# 15 Fairfield Inn & Suites New York Manhattan/Times Square            35000
# 16 Fairfield Inn & Suites New York Midtown Manhattan/Penn Station    35000
# 17 Marriott Vacation Club Pulse, New York City                       35000
# 18 New York Marriott at the Brooklyn Bridge                          35000
# 19 New York Marriott Downtown                                        35000
# 20 Renaissance New York Hotel 57                                     35000
# 21 Residence Inn New York Manhattan/Central Park                     35000
# 22 Residence Inn New York Manhattan/Midtown East                     35000
# 23 Residence Inn New York Manhattan/Times Square                     35000
# 24 Sheraton Brooklyn New York Hotel                                  35000
# 25 Sheraton Tribeca New York Hotel                                   35000
# 26 SpringHill Suites New York Midtown Manhattan/Fifth Avenue         35000
# 27 The Lexington New York City, Autograph Collection                 35000
# 28 The Ritz-Carlton New York, Westchester                            35000
# 29 TownePlace Suites New York Manhattan/Times Square                 35000
# 30 New York Marriott East Side                                       50000
# 31 New York Marriott Marquis                                         50000
# 32 Renaissance New York Midtown Hotel                                50000
# 33 Renaissance New York Times Square Hotel                           50000
# 34 Sheraton New York Times Square Hotel                              50000
# 35 The Westin New York at Times Square                               50000
# 36 The Westin New York Grand Central                                 50000
# 37 W New York \xd0 Downtown                                          50000
# 38 Gramercy Park Hotel, New York, a Member of Design Hotels\xaa      60000
# 39 Hotel Americano, New York, a Member of Design Hotels\xaa          60000
# 40 JW Marriott Essex House New York                                  60000
# 41 The New York EDITION                                              60000
# 42 W New York - Times Square                                         60000
# 43 W New York - Union Square                                         60000

# %%
(DC <- chart %>%
  filter(str_detect(Name, "Washington"), !str_detect(Name, "Airport"), New %in% c(35000, 50000, 60000)) %>%
  select(Name, New))
# Out:
#    Name                                                            New
# 1  Courtyard Washington Capitol Hill/Navy Yard                     35000
# 2  Courtyard Washington Convention Center                          35000
# 3  Courtyard Washington Downtown/Convention Center                 35000
# 4  Courtyard Washington Embassy Row                                35000
# 5  Courtyard Washington, DC/Dupont Circle                          35000
# 6  Courtyard Washington, DC/Foggy Bottom                           35000
# 7  Fairfield Inn & Suites Washington, DC/Downtown                  35000
# 8  Marriott Marquis Washington, DC                                 35000
# 9  Renaissance Washington, DC Downtown Hotel                       35000
# 10 Residence Inn Washington Capitol Hill/Navy Yard                 35000
# 11 Residence Inn Washington Downtown/Convention Center             35000
# 12 Residence Inn Washington, DC Downtown                           35000
# 13 Residence Inn Washington, DC/Capitol                            35000
# 14 Residence Inn Washington, DC/Dupont Circle                      35000
# 15 Residence Inn Washington, DC/Foggy Bottom                       35000
# 16 The Westin Georgetown, Washington D.C.                          35000
# 17 The Westin Washington National Harbor                           35000
# 18 The Westin Washington, D.C. City Center                         35000
# 19 Washington Marriott at Metro Center                             35000
# 20 Washington Marriott Georgetown                                  35000
# 21 Washington Marriott Wardman Park                                35000
# 22 JW Marriott Washington, DC                                      50000
# 23 Marriott Vacation Club Pulse at The Mayflower, Washington, D.C. 50000
# 24 The Ritz-Carlton Georgetown, Washington, D.C.                   60000
# 25 The Ritz-Carlton, Washington, DC                                60000
# 26 The St. Regis Washington, D.C.                                  60000
# 27 W Washington D.C.                                               60000

# %%
(FL <- chart %>%
  filter(str_detect(Name, "Orlando|Miami|Key|Tampa|Fort"), !str_detect(Name, "Airport"), New %in% c(35000, 50000, 60000)) %>%
  select(Name, New))
# Out:
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”ERROR while rich displaying an object: Error in gsub(" &\\", "\\", r, fixed = TRUE): input string 1 is invalid in this locale
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. mime2repr[[mime]](obj)
# 8. repr_latex.data.frame(obj)
# 9. gsub(" &\\", "\\", r, fixed = TRUE)
# Warning message in grepl("<html.*>", data[["text/html"]], ignore.case = TRUE):
# “input string 1 is invalid in this locale”
#    Name                                                     New
# 1  AC Hotel Miami Aventura                                  35000
# 2  AC Hotel Miami Beach                                     35000
# 3  Aloft Miami Aventura                                     35000
# 4  Courtyard Fort Lauderdale Beach                          35000
# 5  Courtyard Key Largo                                      35000
# 6  Courtyard Marathon Florida Keys                          35000
# 7  Courtyard Miami Beach South Beach                        35000
# 8  Fairfield Inn & Suites Key West at The Keys Collection   35000
# 9  Fort Lauderdale Marriott Pompano Beach Resort & Spa      35000
# 10 Four Points by Sheraton Destin-Fort Walton Beach         35000
# 11 Four Points by Sheraton Miami Beach                      35000
# 12 Grand Bohemian Hotel Orlando, Autograph Collection       35000
# 13 JW Marriott Marquis Miami                                35000
# 14 JW Marriott Miami                                        35000
# 15 Key Bridge Marriott                                      35000
# 16 Le M\x8eridien Tampa                                     35000
# 17 Miami Marriott Biscayne Bay                              35000
# 18 Orlando World Center Marriott                            35000
# 19 Renaissance Fort Lauderdale Cruise Port Hotel            35000
# 20 Renaissance Fort Lauderdale-Plantation Hotel             35000
# 21 Residence Inn Fort Lauderdale Intracoastal/Il Lugano     35000
# 22 Residence Inn Miami Beach South Beach                    35000
# 23 Residence Inn Miami Sunny Isles Beach                    35000
# 24 Sheraton Sand Key Resort                                 35000
# 25 Sheraton Suites Key West                                 35000
# 26 Tampa Marriott Waterside Hotel & Marina                  35000
# 27 The Dalmar, Fort Lauderdale, a Tribute Portfolio Hotel   35000
# 28 The Ritz-Carlton Coconut Grove, Miami                    35000
# 29 The Westin Fort Lauderdale                               35000
# 30 The Westin Fort Lauderdale Beach Resort                  35000
# 31 The Worthington Renaissance Fort Worth Hotel             35000
# 32 Turnberry Isle Miami, Autograph Collection               35000
# 33 W Miami                                                  35000
# 34 Clearwater Beach Marriott Suites on Sand Key             50000
# 35 Courtyard Key West Waterfront                            50000
# 36 Fairfield Inn & Suites Key West                          50000
# 37 Fort Lauderdale Marriott Harbor Beach Resort & Spa       50000
# 38 JW Marriott Orlando, Grande Lakes                        50000
# 39 Key Largo Bay Marriott Beach Resort                      50000
# 40 Key West Marriott Beachside Hotel                        50000
# 41 Royal Palm South Beach Miami, a Tribute Portfolio Resort 50000
# 42 Sheraton Vistana Resort Villas, Lake Buena Vista/Orlando 50000
# 43 Sheraton Vistana Villages Resort Villas, I-Drive/Orlando 50000
# 44 The Ritz-Carlton Key Biscayne, Miami                     50000
# 45 The Ritz-Carlton Orlando, Grande Lakes                   50000
# 46 The Saint Hotel Key West, Autograph Collection           50000
# 47 W Fort Lauderdale                                        50000
# 48 The Ritz-Carlton, Fort Lauderdale                        60000

# %%
(HI <- chart %>%
  filter(str_detect(Name, "Kauai|Waikiki|Oahu|Honolulu
                    |Maui|Kaiulani|Keauhou|Hapuna|Princeville
                    |Ka'anapali|Kona|Wailokoloa|Mauna|Kailua|Lahania"), !str_detect(Name, "Airport"), New %in% c(35000, 50000, 60000)) %>%
  select(Name, New))
# Out:
#    Name                                                      New
# 1  Courtyard Oahu North Shore                                35000
# 2  Courtyard Waikiki Beach                                   35000
# 3  Hapuna Beach Resort                                       35000
# 4  Residence Inn Maui Wailea                                 35000
# 5  Sheraton Kauai Resort                                     35000
# 6  Sheraton Kona Resort & Spa at Keauhou Bay                 35000
# 7  Sheraton Princess Kaiulani                                35000
# 8  Marriott's Maui Ocean Club - Lahaina & Napili Towers      50000
# 9  Marriott's Maui Ocean Club - Molokai, Maui & Lanai Towers 50000
# 10 Mauna Kea Beach Hotel, Autograph Collection               50000
# 11 Sheraton Maui Resort & Spa                                50000
# 12 Sheraton Waikiki                                          50000
# 13 The Westin Ka'anapali Ocean Resort Villas                 50000
# 14 The Westin Maui Resort & Spa, Ka'anapali                  50000
# 15 Waikiki Beach Marriott Resort & Spa                       50000
# 16 Wailea Beach Resort - Marriott, Maui                      50000
# 17 Marriott's Kauai Lagoons - Kalanipu'u                     60000
# 18 Moana Surfrider, A Westin Resort & Spa, Waikiki Beach     60000
# 19 The Royal Hawaiian, a Luxury Collection Resort, Waikiki   60000
# 20 The Westin Nanea Ocean Villas, Ka'anapali                 60000

# %%
(TX <- chart %>%
  filter(str_detect(Name, "Dallas|Houston|San Antonio|Austin"), !str_detect(Name, "Airport"),
        New %in% c(35000, 50000, 60000)) %>%
  select(Name, New))
# Out:
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”ERROR while rich displaying an object: Error in gsub(" &\\", "\\", r, fixed = TRUE): input string 1 is invalid in this locale
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. mime2repr[[mime]](obj)
# 8. repr_latex.data.frame(obj)
# 9. gsub(" &\\", "\\", r, fixed = TRUE)
# Warning message in grepl("<html.*>", data[["text/html"]], ignore.case = TRUE):
# “input string 1 is invalid in this locale”
#    Name                                                    New
# 1  Austin Marriott South                                   35000
# 2  Houston Marriott Medical Center/Museum District         35000
# 3  JW Marriott Houston Downtown                            35000
# 4  Le M\x8eridien Dallas, The Stoneleigh                   35000
# 5  Le M\x8eridien Houston Downtown                         35000
# 6  Marriott Marquis Houston                                35000
# 7  Renaissance Austin Hotel                                35000
# 8  San Antonio Marriott Rivercenter                        35000
# 9  San Antonio Marriott Riverwalk                          35000
# 10 Sheraton Austin Hotel at the Capitol                    35000
# 11 The St. Anthony, a Luxury Collection Hotel, San Antonio 35000
# 12 The Westin Austin at The Domain                         35000
# 13 The Westin Austin Downtown                              35000
# 14 The Westin Dallas Downtown                              35000
# 15 The Westin Houston Downtown                             35000
# 16 The Westin Riverwalk, San Antonio                       35000
# 17 W Dallas - Victory                                      35000
# 18 JW Marriott Austin                                      50000
# 19 JW Marriott San Antonio Hill Country Resort & Spa       50000
# 20 The Ritz-Carlton, Dallas                                50000
# 21 The St. Regis Houston                                   50000
# 22 W Austin                                                50000

# %%
(SEA <- chart %>%
  filter(str_detect(Name, "Seattle"), !str_detect(Name, "Airport"),
         New %in% c(35000, 50000, 60000)) %>%
  select(Name, New))
# Out:
#    Name                                                New
# 1  Courtyard Seattle Downtown/Lake Union               35000
# 2  Courtyard Seattle Downtown/Pioneer Square           35000
# 3  Four Points by Sheraton Downtown Seattle Center     35000
# 4  Moxy Seattle Downtown                               35000
# 5  Residence Inn Seattle Downtown/Convention Center    35000
# 6  Residence Inn Seattle Downtown/Lake Union           35000
# 7  Residence Inn Seattle University District           35000
# 8  Sheraton Seattle Hotel                              35000
# 9  SpringHill Suites Seattle Downtown/South Lake Union 35000
# 10 Renaissance Seattle Hotel                           50000
# 11 Seattle Marriott Waterfront                         50000
# 12 The Westin Seattle                                  50000
# 13 W Seattle                                           50000

# %%
(Paris <- chart %>%
  filter(Country == "France", str_detect(Name, "Paris"), !str_detect(Name, "Airport"), New %in% c(35000, 50000, 60000)) %>%
  select(Name, New))
# Out:
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”ERROR while rich displaying an object: Error in gsub(" &\\", "\\", r, fixed = TRUE): input string 1 is invalid in this locale
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. mime2repr[[mime]](obj)
# 8. repr_latex.data.frame(obj)
# 9. gsub(" &\\", "\\", r, fixed = TRUE)
# Warning message in grepl("<html.*>", data[["text/html"]], ignore.case = TRUE):
# “input string 1 is invalid in this locale”
#    Name                                                                New
# 1  Le Dokhan's, a Tribute Portfolio Hotel, Paris                       35000
# 2  Paris Marriott Rive Gauche Hotel & Conference Center                35000
# 3  Renaissance Paris Republique Hotel                                  35000
# 4  Le Metropolitan, a Tribute Portfolio Hotel, Paris                   50000
# 5  Paris Marriott Opera Ambassador Hotel                               50000
# 6  Renaissance Paris Arc de Triomphe Hotel                             50000
# 7  Renaissance Paris Le Parc Trocadero Hotel                           50000
# 8  Renaissance Paris Vendome Hotel                                     50000
# 9  Hotel Bel Ami, Paris, a Member of Design Hotels\xaa                 60000
# 10 Hotel de NELL, Paris, a Member of Design Hotels\xaa                 60000
# 11 Hotel Vernet, Paris, a Member of Design Hotels\xaa                  60000
# 12 La Maison Champs Elys\x8ees, Paris, a Member of Design Hotels\xaa   60000
# 13 Le Roch Hotel and Spa, Paris, a Member of Design Hotels\xaa         60000
# 14 Les Bains, Paris, a Member of Design Hotels\xaa                     60000
# 15 Paris Marriott Champs Elysees Hotel                                 60000
# 16 The Westin Paris - Vend\x99me                                       60000
# 17 W Paris - Op\x8era                                                  60000

# %%
(london <- chart %>%
  filter(str_detect(Name, "London"), !str_detect(Name, "Airport"), New %in% c(35000, 50000, 60000)) %>%
  select(Name, New))
# Out:
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”ERROR while rich displaying an object: Error in gsub(" &\\", "\\", r, fixed = TRUE): input string 1 is invalid in this locale
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. mime2repr[[mime]](obj)
# 8. repr_latex.data.frame(obj)
# 9. gsub(" &\\", "\\", r, fixed = TRUE)
# Warning message in grepl("<html.*>", data[["text/html"]], ignore.case = TRUE):
# “input string 1 is invalid in this locale”
#    Name                                                                New
# 1  London Heathrow Marriott Hotel                                      35000
# 2  London Marriott Hotel Kensington                                    35000
# 3  London Marriott Hotel Maida Vale                                    35000
# 4  London Marriott Hotel Regents Park                                  35000
# 5  London Marriott Hotel West India Quay                               35000
# 6  Residence Inn by Marriott London Bridge                             35000
# 7  Residence Inn London Kensington                                     35000
# 8  Sheraton Skyline Hotel London Heathrow                              35000
# 9  Town Hall Hotel & Apartments, London, a Member of Design Hotels\xaa 35000
# 10 Great Northern Hotel, a Tribute Portfolio Hotel, London             50000
# 11 London Marriott Hotel Marble Arch                                   50000
# 12 St. Pancras Renaissance Hotel London                                50000
# 13 Blakes Hotel London, a Member of Design Hotels\xaa                  60000
# 14 London Marriott Hotel County Hall                                   60000
# 15 London Marriott Hotel Grosvenor Square                              60000
# 16 London Marriott Hotel Park Lane                                     60000
# 17 Sheraton Grand London Park Lane                                     60000
# 18 The London EDITION                                                  60000
# 19 The Park Tower Knightsbridge, a Luxury Collection Hotel, London     60000
# 20 The Westbury, A Luxury Collection Hotel, Mayfair-London             60000
# 21 W London - Leicester Square                                         60000

# %%
(Italy <- chart %>%
  filter(str_detect(Name, "Milan|Roma|Venezia|Firenze|Siena"), !str_detect(Name, "Airport"),
         New %in% c(35000, 50000, 60000)) %>%
  select(Name, New))
# Out:
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”ERROR while rich displaying an object: Error in gsub(" &\\", "\\", r, fixed = TRUE): input string 1 is invalid in this locale
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. mime2repr[[mime]](obj)
# 8. repr_latex.data.frame(obj)
# 9. gsub(" &\\", "\\", r, fixed = TRUE)
# Warning message in grepl("<html.*>", data[["text/html"]], ignore.case = TRUE):
# “input string 1 is invalid in this locale”
#    Name                                                        New
# 1  AC Hotel Firenze                                            35000
# 2  AC Hotel Venezia                                            35000
# 3  Sheraton Diana Majestic, Milan                              35000
# 4  STRAF, Milan, a Member of Design Hotels                     35000
# 5  The Siena Hotel, Autograph Collection                       35000
# 6  The Westin Palace, Milan                                    35000
# 7  Boscolo Milano, Autograph Collection                        50000
# 8  Boscolo Venezia, Autograph Collection                       50000
# 9  Boscolo Exedra Roma, Autograph Collection                   60000
# 10 Excelsior Hotel Gallia, a Luxury Collection Hotel, Milan    60000
# 11 Hotel Viu Milan, a Member of Design Hotels\xaa              60000
# 12 The Romanos, a Luxury Collection Resort, Costa Navarino     60000

# %%
(JP <- chart %>%
  filter(Country == "Japan", New %in% c(35000, 50000, 60000)))
# Out:
#    Name                                                Brand
# 1  Courtyard Shin-Osaka Station                        Courtyard
# 2  Courtyard Tokyo Ginza Hotel                         Courtyard
# 3  Courtyard Tokyo Station                             Courtyard
# 4  Fuji Marriott Hotel Lake Yamanaka                   Marriott
# 5  Izu Marriott Hotel Shuzenji                         Marriott
# 6  Karuizawa Marriott Hotel                            Marriott
# 7  Kobe Bay Sheraton Hotel & Towers                    Sheraton
# 8  Lake Biwa Marriott Hotel                            Marriott
# 9  Moxy Osaka Honmachi                                 Moxy Hotels
# 10 Moxy Tokyo Kinshicho                                Moxy Hotels
# 11 Nagoya Marriott Associa Hotel                       Marriott
# 12 Nanki-Shirahama Marriott Hotel                      Marriott
# 13 Renaissance Naruto Resort                           Renaissance
# 14 Sheraton Grand Hiroshima Hotel                      Sheraton
# 15 Sheraton Grande Ocean Resort                        Sheraton
# 16 Sheraton Hokkaido Kiroro Resort                     Sheraton
# 17 Sheraton Miyako Hotel Osaka                         Sheraton
# 18 The Kiroro, a Tribute Portfolio Hotel, Hokkaido     Tribute Portfolio
# 19 The Westin Awaji Island Resort & Conference Center  Westin
# 20 The Westin Miyako Kyoto                             Westin
# 21 The Westin Osaka                                    Westin
# 22 The Westin Sendai                                   Westin
# 23 Yokohama Bay Sheraton Hotel & Towers                Sheraton
# 24 Okinawa Marriott Resort & Spa                       Marriott
# 25 Osaka Marriott Miyako Hotel                         Marriott
# 26 Renaissance Okinawa Resort                          Renaissance
# 27 Sheraton Grande Tokyo Bay Hotel                     Sheraton
# 28 Sheraton Miyako Hotel Tokyo                         Sheraton
# 29 Sheraton Okinawa Sunmarina Resort                   Sheraton
# 30 The Prince Sakura Tower Tokyo, Autograph Collection Autograph Collection
# 31 The Westin Tokyo                                    Westin
# 32 Tokyo Marriott Hotel                                Marriott
# 33 The Ritz-Carlton, Okinawa                           Ritz-Carlton
# 34 The Ritz-Carlton, Osaka                             Ritz-Carlton
# 35 The Westin Rusutsu Resort                           Westin
#    Country Current New   Difference Category
# 1  Japan   35000   35000      0     5
# 2  Japan   35000   35000      0     5
# 3  Japan   40000   35000  -5000     5
# 4  Japan   35000   35000      0     5
# 5  Japan   35000   35000      0     5
# 6  Japan   35000   35000      0     5
# 7  Japan   30000   35000   5000     5
# 8  Japan   35000   35000      0     5
# 9  Japan   35000   35000      0     5
# 10 Japan   35000   35000      0     5
# 11 Japan   30000   35000   5000     5
# 12 Japan   35000   35000      0     5
# 13 Japan   35000   35000      0     5
# 14 Japan   36000   35000  -1000     5
# 15 Japan   36000   35000  -1000     5
# 16 Japan   36000   35000  -1000     5
# 17 Japan   30000   35000   5000     5
# 18 Japan   30000   35000   5000     5
# 19 Japan   30000   35000   5000     5
# 20 Japan   36000   35000  -1000     5
# 21 Japan   36000   35000  -1000     5
# 22 Japan   36000   35000  -1000     5
# 23 Japan   36000   35000  -1000     5
# 24 Japan   40000   50000  10000     6
# 25 Japan   40000   50000  10000     6
# 26 Japan   40000   50000  10000     6
# 27 Japan   60000   50000 -10000     6
# 28 Japan   36000   50000  14000     6
# 29 Japan   60000   50000 -10000     6
# 30 Japan   40000   50000  10000     6
# 31 Japan   60000   50000 -10000     6
# 32 Japan   40000   50000  10000     6
# 33 Japan   60000   60000      0     7
# 34 Japan   50000   60000  10000     7
# 35 Japan   60000   60000      0     7

# %%
(cat1 <- chart %>%
  filter(Category == 1, Country %in% c("China", "USA")) %>%
  select(Name))
# Out:
#     Name
# 1   Aloft Chengdu Shixiang Lake
# 2   Aloft Cleveland Airport
# 3   Aloft Dalian
# 4   Aloft Dongguan Dynamic Town
# 5   Aloft Dongguan Songshan Lake
# 6   Aloft Guangzhou Tianhe
# 7   Aloft Guangzhou University Park
# 8   Aloft Haiyang
# 9   Aloft Nanhai, Foshan
# 10  Aloft Tulsa
# 11  Aloft Yancheng
# 12  Aloft Zhengzhou Shangjie
# 13  Aloft Zhengzhou Zhengdong New District
# 14  Courtyard Boluo
# 15  Courtyard Bridgeport Clarksburg
# 16  Courtyard Changsha South
# 17  Courtyard Chicago Elgin/West Dundee
# 18  Courtyard Chicago Wood Dale/Itasca
# 19  Courtyard Harlingen
# 20  Courtyard Houma
# 21  Courtyard Houston Hobby Airport
# 22  Courtyard Houston Northwest
# 23  Courtyard Huntsville University Drive
# 24  Courtyard Jackson Ridgeland
# 25  Courtyard Jacksonville
# 26  Courtyard Killeen
# 27  Courtyard Kunshan
# 28  Courtyard Lafayette Airport
# 29  Courtyard Little Rock West
# 30  Courtyard Lufkin
# ⋮   ⋮
# 178 TownePlace Suites Albany University Area
# 179 TownePlace Suites Albuquerque Airport
# 180 TownePlace Suites Baton Rouge South
# 181 TownePlace Suites Beaumont Port Arthur
# 182 TownePlace Suites Bridgeport Clarksburg
# 183 TownePlace Suites Chicago Elgin/West Dundee
# 184 TownePlace Suites Cleveland Airport
# 185 TownePlace Suites Cleveland Streetsboro
# 186 TownePlace Suites Dickinson
# 187 TownePlace Suites Dodge City
# 188 TownePlace Suites Eagle Pass
# 189 TownePlace Suites Garden City
# 190 TownePlace Suites Gillette
# 191 TownePlace Suites Goldsboro
# 192 TownePlace Suites Hobbs
# 193 TownePlace Suites Houston Energy Corridor/Katy Freeway
# 194 TownePlace Suites Houston I-10 East
# 195 TownePlace Suites Houston Northwest
# 196 TownePlace Suites Huntsville
# 197 TownePlace Suites Huntsville West/Redstone Gateway
# 198 TownePlace Suites Jacksonville
# 199 TownePlace Suites Killeen
# 200 TownePlace Suites McAllen Edinburg
# 201 TownePlace Suites Richmond (VA)
# 202 TownePlace Suites Texarkana
# 203 TownePlace Suites Tulsa Broken Arrow
# 204 TownePlace Suites Tulsa North/Owasso
# 205 TownePlace Suites Vernal
# 206 TownePlace Suites Wichita East
# 207 TownePlace Suites Winchester

# %%
(package <- chart %>%
  filter(Country %in% c("USA", "China"), New == 25000) %>%
  select(Name))
# Out:
#      Name
# 1    AC Hotel Atlanta Downtown
# 2    AC Hotel Bloomington Mall of America
# 3    AC Hotel Chapel Hill Downtown
# 4    AC Hotel Charlotte City Center
# 5    AC Hotel Chicago Downtown
# 6    AC Hotel Cincinnati at The Banks
# 7    AC Hotel Dallas Downtown
# 8    AC Hotel Denver Downtown
# 9    AC Hotel Gainesville Downtown
# 10   AC Hotel Irvine
# 11   AC Hotel Madison Downtown
# 12   AC Hotel Minneapolis Downtown
# 13   AC Hotel National Harbor Washington, DC Area
# 14   AC Hotel New Orleans Bourbon
# 15   AC Hotel New York Downtown
# 16   AC Hotel Oklahoma City Bricktown
# 17   AC Hotel Phoenix Tempe/Downtown
# 18   AC Hotel Raleigh North Hills
# 19   AC Hotel Salt Lake City Downtown
# 20   AC Hotel San Jose Downtown
# 21   AC Hotel San Jose Sunnyvale Cupertino
# 22   AC Hotel Seattle Bellevue/Downtown
# 23   AC Hotel Tampa Airport
# 24   AC Hotel Worcester
# 25   Albany Marriott
# 26   Aloft Atlanta Downtown
# 27   Aloft Austin at The Domain
# 28   Aloft Austin Downtown
# 29   Aloft Birmingham Soho Square
# 30   Aloft Charleston Airport & Convention Center
# ⋮    ⋮
# 1184 TownePlace Suites Oxford
# 1185 TownePlace Suites Providence North Kingstown
# 1186 TownePlace Suites Redding
# 1187 TownePlace Suites Redwood City Redwood Shores
# 1188 TownePlace Suites Republic Airport Long Island/Farmingdale
# 1189 TownePlace Suites San Antonio Downtown
# 1190 TownePlace Suites San Jose Campbell
# 1191 TownePlace Suites San Jose Cupertino
# 1192 TownePlace Suites San Jose Santa Clara
# 1193 TownePlace Suites Seattle Southcenter
# 1194 TownePlace Suites St. George
# 1195 TownePlace Suites Sunnyvale Mountain View
# 1196 TownePlace Suites Thousand Oaks Ventura County
# 1197 TownePlace Suites Wareham Buzzards Bay
# 1198 TownePlace Suites Whitefish
# 1199 Towson University Marriott Conference Hotel
# 1200 Tucson Marriott University Park
# 1201 Tysons Corner Marriott
# 1202 Visalia Marriott at the Convention Center
# 1203 W Beijing - Chang'an
# 1204 W Suzhou
# 1205 Walnut Creek Marriott
# 1206 Washington Dulles Airport Marriott
# 1207 Washington Dulles Marriott Suites
# 1208 WATERMARK Baton Rouge, Autograph Collection
# 1209 West Des Moines Marriott
# 1210 Westchester Marriott
# 1211 Westfields Marriott Washington Dulles
# 1212 Winston-Salem Marriott
# 1213 World Golf Village Renaissance St. Augustine Resort
